# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies_dataset.csv')
df.head(3)
# Out:
#    adult                     backdrop_path                  genre_ids  \
# 0  False  /e4OnHU8HNAhdS6C4Ypk6NA26kPQ.jpg               [28, 35, 80]
# 1  False  /tyjXlexbNZQ0ZT1KEJslQtBirqc.jpg              [12, 53, 878]
# 2  False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  [16, 35, 12, 10751, 9648]
#
#         id original_language          original_title  \
# 0  1168190                en       The Wrecking Crew
# 1   840464                en  Greenland 2: Migration
# 2  1084242                en              Zootopia 2
#
#                                             overview  popularity  \
# 0  Estranged half-brothers Jonny and James reunit...    673.3304
# 1  Having found the safety of the Greenland bunke...    624.2323
# 2  After cracking the biggest case in Zootopia's ...    340.0179
#
#                         poster_path release_date                   title  \
# 0  /gbVwHl4YPSq6BcC92TQpe7qUTh6.jpg   2026-01-28       The Wrecking Crew
# ...

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.columns = ['adulto', 'caminho_do_pano_de_fundo', 'id_dos_gêneros', 'id', 'idioma_original',
'título_original', 'visão_geral', 'popularidade', 'caminho_do_pôster',
'data_de_lançamento', 'título', 'vídeo', 'média_de_votos', 'contagem_de_votos']
df.head(3)
# Out:
#    adulto          caminho_do_pano_de_fundo             id_dos_gêneros  \
# 0   False  /e4OnHU8HNAhdS6C4Ypk6NA26kPQ.jpg               [28, 35, 80]
# 1   False  /tyjXlexbNZQ0ZT1KEJslQtBirqc.jpg              [12, 53, 878]
# 2   False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  [16, 35, 12, 10751, 9648]
#
#         id idioma_original         título_original  \
# 0  1168190              en       The Wrecking Crew
# 1   840464              en  Greenland 2: Migration
# 2  1084242              en              Zootopia 2
#
#                                          visão_geral  popularidade  \
# 0  Estranged half-brothers Jonny and James reunit...      673.3304
# 1  Having found the safety of the Greenland bunke...      624.2323
# 2  After cracking the biggest case in Zootopia's ...      340.0179
#
#                   caminho_do_pôster data_de_lançamento  \
# 0  /gbVwHl4YPSq6BcC92TQpe7qUTh6.jpg         2026-01-28
# 1  /1mF4othta76CEXcL1YFInYudQ7K.jpg         2026-01-07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   adulto                    10000 non-null  bool
#  1   caminho_do_pano_de_fundo  7023 non-null   object
#  2   id_dos_gêneros            10000 non-null  object
#  3   id                        10000 non-null  int64
#  4   idioma_original           10000 non-null  object
#  5   título_original           10000 non-null  object
#  6   visão_geral               9650 non-null   object
#  7   popularidade              10000 non-null  float64
#  8   caminho_do_pôster         9242 non-null   object
#  9   data_de_lançamento        9852 non-null   object
#  10  título                    10000 non-null  object
#  11  vídeo                     10000 non-null  bool
#  12  média_de_votos            10000 non-null  float64
# ...

# %%
df['idioma_original'].unique()
# Out:
# array(['en', 'zh', 'hi', 'de', 'te', 'ko', 'ja', 'th', 'fr', 'ta', 'tl',
#        'pt', 'fi', 'es', 'ml', 'id', 'tr', 'it', 'kn', 'no', 'ru', 'ms',
#        'sr', 'ca', 'nl', 'da', 'cn', 'sv', 'lv', 'el', 'cs', 'hu', 'pl',
#        'is', 'sl', 'ro', 'hr', 'bs', 'uk', 'ar', 'bn', 'sh', 'sk', 'eu',
#        'et', 'fa', 'xx', 'pa', 'sq', 'af', 'ne', 'ku', 'yi', 'mr', 'zu',
#        'bg', 'ur', 'he', 'ab', 'mk', 'lt', 'jv', 'az', 'hy', 'cy', 'vi',
#        'mn', 'ga', 'gu', 'as', 'qu', 'xh', 'wo'], dtype=object)

# %%
df['média_de_votos'].value_counts().head(10)
# Out:
# média_de_votos
# 0.0    2165
# 6.0     361
# 5.0     341
# 7.0     230
# 5.5     169
# 6.5     148
# 4.0     126
# 6.2     122
# 5.7     117
# 5.8     116
# Name: count, dtype: int64

# %%
valores_baixo = df['média_de_votos'] == 0
df[valores_baixo].head(3)
# Out:
#      adulto          caminho_do_pano_de_fundo       id_dos_gêneros       id  \
# 82    False                               NaN      [99, 36, 10752]  1409999
# 101   False  /wDKJqWo8bwqdJCPQJNemeRDioKI.jpg                   []  1483088
# 119   False  /4lo5yNZrMLPKBh47t2CoZkbAUur.jpg  [16, 35, 10751, 28]  1297842
#
#     idioma_original                           título_original  \
# 82               en  World War II: A History of WWII (Part 2)
# 101              tr                                Aşkın Yüzü
# 119              en                                      GOAT
#
#                                            visão_geral  popularidade  \
# 82   This documentary begins with the story of the ...       33.4954
# 101  High school student Özgür has a rare disease: ...       25.2208
# 119  Will, a small goat with big dreams, gets a onc...       24.7503
#
#                     caminho_do_pôster data_de_lançamento  \
# 82   /f7fbDkpe5PcEBdgBs1qnwCcOWD7.jpg         2001-01-01
# ...

# %%
df['contagem_de_votos'].value_counts()
# Out:
# contagem_de_votos
# 0        2162
# 1         749
# 2         556
# 3         401
# 4         293
#          ...
# 6276        1
# 6846        1
# 1254        1
# 377         1
# 10363       1
# Name: count, Length: 1442, dtype: int64

# %%
df['idioma_original'].value_counts(normalize=True) * 100
# Out:
# idioma_original
# en    57.67
# fr     5.06
# de     3.99
# es     3.93
# ja     3.38
#       ...
# az     0.01
# jv     0.01
# ab     0.01
# ku     0.01
# wo     0.01
# Name: proportion, Length: 73, dtype: float64

# %%
df
